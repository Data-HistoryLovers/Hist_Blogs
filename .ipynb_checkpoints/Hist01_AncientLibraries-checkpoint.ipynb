# %% [markdown]
# # Using Wikipedia, Pandas, and Folium visualize all the Ancient Libraries and Where they were

# %% [markdown]
# # Packages

# %%
import pandas as pd
import wikipedia
import geopandas as gpd
# %matplotlib inline  
import folium
import os
import regex as re
import numpy as np
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import fuzzywuzzy.process as fwp

# %% [markdown]
# # Variables

# %%
w_page = "List of libraries in the ancient world"
col_names = ["RAW_TEXT", "NAME", "EXTRA"]
output_table = "test.csv"
countries = "ne_50m_admin_0_countries.shp"

# %% [markdown]
# # Read in Wiki page as variable

# %%
w_page = wikipedia.page(w_page)
text = w_page.content

# %% [markdown]
# # Save as text and read back in

# %%
open('temp.txt', 'a').close()
with open('temp.txt', "w", encoding="utf-8") as f:
    f.write(text)

# %% [markdown]
# # Read text into pandas and split text up

# %%
df = pd.read_csv('temp.txt', sep = '==',  header = None, skiprows =1)
df.columns = col_names
df
# Out:
# C:\Users\fcmun\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#                                              RAW_TEXT              NAME  EXTRA
# 0                                                 NaN          Algeria     NaN
# 1   Timgad (250 A.D.) (modern Algeria)The library ...              None    NaN
# 2                                                 NaN         Anatolia     NaN
# 3   Hattusa (1900 B.C. - 1190 B.C.) (modern Bogazk...              None    NaN
# 4   Royal Library of Antioch (221 B.C. - 363 A.D.)...              None    NaN
# 5   Library of Pergamum (197 B.C. - 159 B.C.) (mod...              None    NaN
# 6   Library of Celsus (135 A.D. - 262) (located wi...              None    NaN
# 7   The Imperial Library of Constantinople  (337â€...              None    NaN
# 8                                                 NaN            China     NaN
# 9   Han Imperial Library. Catalogue preserved in t...              None    NaN
# 10  Qin reign (third century BCE): It was the prac...              None    NaN
# 11  Tang dynasty (6thâ€“10th century): The Tang Dy...              None    NaN
# 12                                                NaN            Egypt     NaN
# 13  The Royal Library of Alexandria, Egypt, fl. 3r...              None    NaN
# 14  Serapeum of Alexandria, offshoot collection of...              None    NaN
# 15  Temple of Edfu Archive/Library (237â€“57 B.C.)...              None    NaN
# 16                                                NaN         Ethiopia     NaN
# 17  The Library of AksumThe kingdom of Aksum, by t...              None    NaN
# 18                                                NaN           Greece     NaN
# 19  The Library of Aristotle (Athens) (384â€“321 B...              None    NaN
# 20  Kos Library (Kos) (100 A.D.)The library was a ...              None    NaN
# 21  The Library of Pantainos (Athens) (100 A.D.)De...              None    NaN
# 22  The Library of Rhodes (Rhodes) (100 A.D.)The l...              None    NaN
# 23                                                NaN            India     NaN
# 24  The great seats of learning in the ancient Ind...              None    NaN
# 25  Takshasila (6th to 5th century BC in modern-da...              None    NaN
# 26  Nalanda (founded in 427) was considered "one o...              None    NaN
# 27                          Vikramshila (8th century)              None    NaN
# 28  Kanchipuram and other universities, also maint...              None    NaN
# 29                                                NaN             Iran     NaN
# 30  The Academy of Gondishapur in western Iran, es...              None    NaN
# 31                                                NaN             Iraq     NaN
# 32  The Library of Ashurbanipal (established 668â€...              None    NaN
# 33  Nippur temple library (2500 B.C.)The earliest ...              None    NaN
# 34  Nuzi (Modern Yorgan Tepe) (1500 B.C.)This arch...              None    NaN
# 35  The House of Wisdom (Baghdad) (9thâ€“13th cent...              None    NaN
# 36                                                NaN            Italy     NaN
# 37  Libraries of the Forum, consisted of separate ...              None    NaN
# 38  Atrium Liberatatis public library of Asinius P...              None    NaN
# 39  The Villa of the Papyri, in Herculaneum, Italy...              None    NaN
# 40                                                NaN           Israel     NaN
# 41  The Theological Library of Caesarea Maritima, ...              None    NaN
# 42                                                NaN            Syria     NaN
# 43  Ebla (2500 B.C. â€“ 2250 B.C.)Constitute the o...              None    NaN
# 44  Ugarit (Modern Ras Shamra) (1200 B.C.)Several ...              None    NaN
# 45  Tell Leilan (Northeast Syria) (1900 B.C.)This ...              None    NaN
# 46  Mari (Modern Tell Hariri) (1900 B.C.)The archi...              None    NaN
# 47  Sufiya Mosque Library, Grand Umayyad Mosque (A...              None    NaN
# 48                                                NaN         See also     NaN
# 49                        List of destroyed libraries              None    NaN
# 50                                  Apellicon of Teos              None    NaN
# 51                                                NaN            Notes     NaN
# 52                                                NaN       References     NaN
# 53  Johnson, Elmer D. (1965) A History of Librarie...              None    NaN
# 54                                                NaN   External links     NaN
# 55  Edwin Wiley (1920). "Libraries, Ancient" . Enc...              None    NaN

# %% [markdown]
# # Fill NAME column populating the country for each library

# %%
df.iloc[:, 1] = df.iloc[:, 1].fillna(method='ffill')
df2 = df[pd.notnull(df.iloc[:, 0])]
df2 = df2[~df2.NAME.str.contains('External links|See also|References')]
df2 = df2 = df2[~df2.RAW_TEXT.str.contains('Qin reign|Tang dynasty|The great seats of learning')]

# %% [markdown]
# # Initial Cleanup

# %%
##Strip extra characters and fix one country issue
df2.iloc[:, 1] = df2.iloc[:, 1].str.replace('=','')
df2.iloc[:, 1] = df2.iloc[:, 1].str.replace(' ','')
df2.iloc[:, 1] = df2.iloc[:, 1].str.replace('Anatolia','Turkey')

# %%
##Initial work to seperate text contained in paranthesis - both dates and locations
split1 = df2['RAW_TEXT'].str.split('(', n = 1, expand = True)
df2['Temp'] = split1[1]
split2 = df2['Temp'].str.split(')', n = 1, expand = True)
df2['Date'] = split2[0]
df2['Temp2'] = split2[1]
split3 = df2['Temp2'].str.split('(', n = 1, expand = True)
split4 = split3[1].str.split(')', n = 1, expand = True)
df2['Loc'] = split4[0]
df2['Extra'] = split4[1]
split1 = split1[0].str.split(',', n = 1, expand = True)
split1 = split1[0].str.split('.', n = 1, expand = True)
df2['Library'] = split1[0]
df2 = df2.drop(['Temp', 'Temp2'], axis=1)
df2
# Out:
#                                              RAW_TEXT      NAME  EXTRA  \
# 1   Timgad (250 A.D.) (modern Algeria)The library ...   Algeria    NaN
# 3   Hattusa (1900 B.C. - 1190 B.C.) (modern Bogazk...    Turkey    NaN
# 4   Royal Library of Antioch (221 B.C. - 363 A.D.)...    Turkey    NaN
# 5   Library of Pergamum (197 B.C. - 159 B.C.) (mod...    Turkey    NaN
# 6   Library of Celsus (135 A.D. - 262) (located wi...    Turkey    NaN
# 7   The Imperial Library of Constantinople  (337â€...    Turkey    NaN
# 9   Han Imperial Library. Catalogue preserved in t...     China    NaN
# 13  The Royal Library of Alexandria, Egypt, fl. 3r...     Egypt    NaN
# 14  Serapeum of Alexandria, offshoot collection of...     Egypt    NaN
# 15  Temple of Edfu Archive/Library (237â€“57 B.C.)...     Egypt    NaN
# 17  The Library of AksumThe kingdom of Aksum, by t...  Ethiopia    NaN
# 19  The Library of Aristotle (Athens) (384â€“321 B...    Greece    NaN
# 20  Kos Library (Kos) (100 A.D.)The library was a ...    Greece    NaN
# 21  The Library of Pantainos (Athens) (100 A.D.)De...    Greece    NaN
# 22  The Library of Rhodes (Rhodes) (100 A.D.)The l...    Greece    NaN
# 25  Takshasila (6th to 5th century BC in modern-da...     India    NaN
# 26  Nalanda (founded in 427) was considered "one o...     India    NaN
# 27                          Vikramshila (8th century)     India    NaN
# 28  Kanchipuram and other universities, also maint...     India    NaN
# 30  The Academy of Gondishapur in western Iran, es...      Iran    NaN
# 32  The Library of Ashurbanipal (established 668â€...      Iraq    NaN
# 33  Nippur temple library (2500 B.C.)The earliest ...      Iraq    NaN
# 34  Nuzi (Modern Yorgan Tepe) (1500 B.C.)This arch...      Iraq    NaN
# 35  The House of Wisdom (Baghdad) (9thâ€“13th cent...      Iraq    NaN
# 37  Libraries of the Forum, consisted of separate ...     Italy    NaN
# 38  Atrium Liberatatis public library of Asinius P...     Italy    NaN
# 39  The Villa of the Papyri, in Herculaneum, Italy...     Italy    NaN
# 41  The Theological Library of Caesarea Maritima, ...    Israel    NaN
# 43  Ebla (2500 B.C. â€“ 2250 B.C.)Constitute the o...     Syria    NaN
# 44  Ugarit (Modern Ras Shamra) (1200 B.C.)Several ...     Syria    NaN
# 45  Tell Leilan (Northeast Syria) (1900 B.C.)This ...     Syria    NaN
# 46  Mari (Modern Tell Hariri) (1900 B.C.)The archi...     Syria    NaN
# 47  Sufiya Mosque Library, Grand Umayyad Mosque (A...     Syria    NaN
#
#                                             Date  \
# 1                                       250 A.D.
# 3                          1900 B.C. - 1190 B.C.
# 4                            221 B.C. - 363 A.D.
# 5                            197 B.C. - 159 B.C.
# 6                                 135 A.D. - 262
# 7                 337â€“361 A.D. â€“ 29 May 1453
# 9                                           None
# 13                                     c. 295 BC
# 14                                          None
# 15                                 237â€“57 B.C.
# 17                                          None
# 19                                        Athens
# 20                                           Kos
# 21                                        Athens
# 22                                        Rhodes
# 25  6th to 5th century BC in modern-day Pakistan
# 26                                founded in 427
# 27                                   8th century
# 28                                          None
# 30                                          None
# 32                      established 668â€“627 BC
# 33                                     2500 B.C.
# 34                            Modern Yorgan Tepe
# 35                                       Baghdad
# 37                                          None
# 38                                          None
# 39                                          None
# 41                                          None
# 43                       2500 B.C. â€“ 2250 B.C.
# 44                             Modern Ras Shamra
# 45                               Northeast Syria
# 46                            Modern Tell Hariri
# 47                                        Aleppo
#
#                                    Loc  \
# 1                       modern Algeria
# 3                      modern Bogazkoy
# 4                       Modern Antakya
# 5                       modern Bergama
# 6   located within the city of Ephesus
# 7      Constantinople, modern Istanbul
# 9                                 None
# 13                                None
# 14                                None
# 15                                None
# 17                                None
# 19                      384â€“321 B.C.
# 20                            100 A.D.
# 21                            100 A.D.
# 22                            100 A.D.
# 25                                None
# 26                                None
# 27                                None
# 28                                None
# 30                                None
# 32             near modern Mosul, Iraq
# 33                                None
# 34                           1500 B.C.
# 35                9thâ€“13th centuries
# 37                                None
# 38                                None
# 39                                None
# 41                                None
# 43                                None
# 44                           1200 B.C.
# 45                           1900 B.C.
# 46                           1900 B.C.
# 47                        12th Century
#
#                                                 Extra  \
# 1   The library was a gift to the Roman people and...
# 3   This archive constituted the largest collectio...
# 4   The library was commissioned in the third cent...
# 5   The Attalid kings formed the second best Helle...
# 6   This library was part of the triumvirate of li...
# 7   The library was established by Constantius II ...
# 9                                                None
# 13                                               None
# 14                                               None
# 15                                               None
# 17                                               None
# 19  The Library of Aristotle was a private library...
# 20  The library was a local public library situate...
# 21  Dedicated to both Athena Archegetis and the Ro...
# 22  The library on the island of Rhodes was a dist...
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 30                                               None
# 32  Long considered to be the first systematically...
# 33                                               None
# 34  This archive consisted of over 6,000 tablets w...
# 35  An Abbasid-era library and Arabic translation ...
# 37                                               None
# 38                                               None
# 39                                               None
# 41                                               None
# 43                                               None
# 44  Several thousand texts consisting of diplomati...
# 45   This archive housed over a thousand clay tablets
# 46  The archive held approximately 15,000 tablets ...
# 47  More than 10,000 volumes were housed in this l...
#
#                                               Library
# 1                                             Timgad
# 3                                            Hattusa
# 4                           Royal Library of Antioch
# 5                                Library of Pergamum
# 6                                  Library of Celsus
# 7            The Imperial Library of Constantinople
# 9                                Han Imperial Library
# 13                    The Royal Library of Alexandria
# 14                             Serapeum of Alexandria
# 15                    Temple of Edfu Archive/Library
# 17           The Library of AksumThe kingdom of Aksum
# 19                          The Library of Aristotle
# 20                                       Kos Library
# 21                          The Library of Pantainos
# 22                             The Library of Rhodes
# 25                                        Takshasila
# 26                                           Nalanda
# 27                                       Vikramshila
# 28                 Kanchipuram and other universities
# 30         The Academy of Gondishapur in western Iran
# 32                       The Library of Ashurbanipal
# 33                             Nippur temple library
# 34                                              Nuzi
# 35                               The House of Wisdom
# 37                             Libraries of the Forum
# 38  Atrium Liberatatis public library of Asinius P...
# 39                            The Villa of the Papyri
# 41       The Theological Library of Caesarea Maritima
# 43                                              Ebla
# 44                                            Ugarit
# 45                                       Tell Leilan
# 46                                              Mari
# 47                              Sufiya Mosque Library

# %% [markdown]
# # Add links to table

# %%
libs = list(df2['Library'])
a = []
for w in libs: 
    try:
        page = wikipedia.page(w)
        a.append(page.url)
    except:
        pass # doing nothing on exception
df_tmp = pd.DataFrame(a)
df_tmp = df_tmp.rename(columns={df_tmp.columns[0]: "Links" })
df_tmp['tmp']= df_tmp['Links'].replace('https://en.wikipedia.org/wiki/', '', regex=True)
df_tmp['tmp']= df_tmp['tmp'].replace('_', ' ', regex=True)
# Out:
# C:\Users\fcmun\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\fcmun\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
choices = list(df_tmp.tmp)
def fmatch(row): 
    minscore=90 #or whatever score works for you
    choice,score = fwp.extractOne(row.Library,choices)
    return choice if score > minscore else None

df2['test'] = df2.apply(fmatch, axis=1)
df3= pd.merge(df2, 
                  df_tmp,
                  left_on='test',
                  right_on='tmp',
                  how = 'left') 
df3['Links']= df3['Links'].replace(np.nan, 'None', regex=True)

# %% [markdown]
# # Work to put dates and locations in correct columns.

# %%
#Putting all Dates that are in three different columns into one
df3['Date_F'] = np.where(df3['Date'].str.contains('A.D.|B.C.|cent|Cent'), df3['Date'], 0)
df3['Date_Temp'] = np.where(df3['Loc'].str.contains('A.D.|B.C.|cent|Cent'), df3['Loc'], 0)
df3.loc[df3["Date_F"]==0,'Date_F'] = df3['Date_Temp']
df3 = df3.drop(['Date_Temp'], axis=1)

# %%
#Putting locations that are in three different columns into one
df3['Loc_F'] = np.where(df3['Loc'].str.contains(r"[a-z]"), df3['Loc'], 0)
df3['Loc_F'] = np.where(~df3['Loc_F'].str.contains('cent|Cent', na = False), df3['Loc_F'], 0)
df3['Loc_Temp'] = np.where(df3['Date'].str.contains(r"[a-z]"), df3['Date'], 0)
df3['Loc_Temp'] = np.where(~df3['Loc_Temp'].str.contains(r"[0-9]|Cent|cent", na = False), df3['Loc_Temp'], 0)
df3.loc[df3["Loc_F"]==0,'Loc_F'] = df3['Loc_Temp']
df3 = df3.drop(['Loc_Temp', 'Date', 'Loc'], axis=1)

# %% [markdown]
# # Focus on creating start and end dates

# %%
##Start Date
split_date = df3['Date_F'].str.split('-|â€“|to', n = 2, expand = True)
split_date[3] = np.where(split_date[1].str.contains('B.C.|BC', na=False), " B.C.", '')
split_date[4] = np.where(~split_date[0].str.contains('B.C.|A.D.|Cent|Cent', na=False), split_date[0] + split_date[3], split_date[0])
split_date[5] = np.where(split_date[1].str.contains('A.D.', na=False), " A.D.", '')
split_date[4] = np.where(~split_date[4].str.contains('B.C.|A.D.|Cent|Cent', na=False), split_date[0] + split_date[5], split_date[4])
split_date[5] = np.where(split_date[1].str.contains('A.D.', na=False), " A.D.", '')
split_date[4] = np.where(~split_date[4].str.contains('B.C.|A.D.|Cent|Cent', na=False), split_date[0] + split_date[5], split_date[4])
##Cheat
split_date[4].replace({'8th century': '8 A.D.'},inplace =True)
split_date[4].replace({'third century BCE': '3 B.C.'},inplace =True)
split_date[4].replace({'12th Century': '12 A.D.'},inplace =True)
split_date[4].replace({'9th': '9 A.D.'},inplace =True)
##End Date
split_date[6] = np.where(split_date[0].str.contains('A.D.', na=False), " A.D.", '')
split_date[7] = np.where(~split_date[1].str.contains('B.C.|A.D.|Cent|Cent|None', na=False), split_date[1] + split_date[6], split_date[1])
##Cheat
split_date[7].replace({'10th century': '10 A.D.'},inplace =True)
split_date[7].replace({'13th centuries': '13 A.D.'},inplace =True)
split_date[7].replace({' 5th century BC in modern': '5 B.C.'},inplace =True)
split_date = split_date.drop([2, 3,5,6], axis=1)

# %%
##Adding dates back in and removing not needed columns
df3['Start_Date'] = split_date[4]
df3['End_Date'] = split_date[7]
df3 = df3.drop(['EXTRA', 'Date_F'], axis=1)
df3.head()
# Out:
#                                             RAW_TEXT     NAME  \
# 0  Timgad (250 A.D.) (modern Algeria)The library ...  Algeria
# 1  Hattusa (1900 B.C. - 1190 B.C.) (modern Bogazk...   Turkey
# 2  Royal Library of Antioch (221 B.C. - 363 A.D.)...   Turkey
# 3  Library of Pergamum (197 B.C. - 159 B.C.) (mod...   Turkey
# 4  Library of Celsus (135 A.D. - 262) (located wi...   Turkey
#
#                                                Extra  \
# 0  The library was a gift to the Roman people and...
# 1  This archive constituted the largest collectio...
# 2  The library was commissioned in the third cent...
# 3  The Attalid kings formed the second best Helle...
# 4  This library was part of the triumvirate of li...
#
#                      Library                 test  \
# 0                    Timgad                Timgad
# 1                   Hattusa               Hattusa
# 2  Royal Library of Antioch    Library of Antioch
# 3       Library of Pergamum   Library of Pergamum
# 4         Library of Celsus     Library of Celsus
#
#                                                Links                  tmp  \
# 0               https://en.wikipedia.org/wiki/Timgad               Timgad
# 1              https://en.wikipedia.org/wiki/Hattusa              Hattusa
# 2   https://en.wikipedia.org/wiki/Library_of_Antioch   Library of Antioch
# 3  https://en.wikipedia.org/wiki/Library_of_Pergamum  Library of Pergamum
# 4    https://en.wikipedia.org/wiki/Library_of_Celsus    Library of Celsus
#
#                                 Loc_F  Start_Date    End_Date
# 0                      modern Algeria    250 A.D.         NaN
# 1                     modern Bogazkoy  1900 B.C.    1190 B.C.
# 2                      Modern Antakya   221 B.C.     363 A.D.
# 3                      modern Bergama   197 B.C.     159 B.C.
# 4  located within the city of Ephesus   135 A.D.     262 A.D.

# %%
df3
# Out:
#                                              RAW_TEXT      NAME  \
# 0   Timgad (250 A.D.) (modern Algeria)The library ...   Algeria
# 1   Hattusa (1900 B.C. - 1190 B.C.) (modern Bogazk...    Turkey
# 2   Royal Library of Antioch (221 B.C. - 363 A.D.)...    Turkey
# 3   Library of Pergamum (197 B.C. - 159 B.C.) (mod...    Turkey
# 4   Library of Celsus (135 A.D. - 262) (located wi...    Turkey
# 5   The Imperial Library of Constantinople  (337â€...    Turkey
# 6   Han Imperial Library. Catalogue preserved in t...     China
# 7   The Royal Library of Alexandria, Egypt, fl. 3r...     Egypt
# 8   Serapeum of Alexandria, offshoot collection of...     Egypt
# 9   Temple of Edfu Archive/Library (237â€“57 B.C.)...     Egypt
# 10  The Library of AksumThe kingdom of Aksum, by t...  Ethiopia
# 11  The Library of Aristotle (Athens) (384â€“321 B...    Greece
# 12  Kos Library (Kos) (100 A.D.)The library was a ...    Greece
# 13  The Library of Pantainos (Athens) (100 A.D.)De...    Greece
# 14  The Library of Rhodes (Rhodes) (100 A.D.)The l...    Greece
# 15  Takshasila (6th to 5th century BC in modern-da...     India
# 16  Nalanda (founded in 427) was considered "one o...     India
# 17                          Vikramshila (8th century)     India
# 18  Kanchipuram and other universities, also maint...     India
# 19  The Academy of Gondishapur in western Iran, es...      Iran
# 20  The Library of Ashurbanipal (established 668â€...      Iraq
# 21  Nippur temple library (2500 B.C.)The earliest ...      Iraq
# 22  Nuzi (Modern Yorgan Tepe) (1500 B.C.)This arch...      Iraq
# 23  The House of Wisdom (Baghdad) (9thâ€“13th cent...      Iraq
# 24  Libraries of the Forum, consisted of separate ...     Italy
# 25  Atrium Liberatatis public library of Asinius P...     Italy
# 26  The Villa of the Papyri, in Herculaneum, Italy...     Italy
# 27  The Theological Library of Caesarea Maritima, ...    Israel
# 28  Ebla (2500 B.C. â€“ 2250 B.C.)Constitute the o...     Syria
# 29  Ugarit (Modern Ras Shamra) (1200 B.C.)Several ...     Syria
# 30  Tell Leilan (Northeast Syria) (1900 B.C.)This ...     Syria
# 31  Mari (Modern Tell Hariri) (1900 B.C.)The archi...     Syria
# 32  Sufiya Mosque Library, Grand Umayyad Mosque (A...     Syria
#
#                                                 Extra  \
# 0   The library was a gift to the Roman people and...
# 1   This archive constituted the largest collectio...
# 2   The library was commissioned in the third cent...
# 3   The Attalid kings formed the second best Helle...
# 4   This library was part of the triumvirate of li...
# 5   The library was established by Constantius II ...
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  The Library of Aristotle was a private library...
# 12  The library was a local public library situate...
# 13  Dedicated to both Athena Archegetis and the Ro...
# 14  The library on the island of Rhodes was a dist...
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  Long considered to be the first systematically...
# 21                                               None
# 22  This archive consisted of over 6,000 tablets w...
# 23  An Abbasid-era library and Arabic translation ...
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29  Several thousand texts consisting of diplomati...
# 30   This archive housed over a thousand clay tablets
# 31  The archive held approximately 15,000 tablets ...
# 32  More than 10,000 volumes were housed in this l...
#
#                                               Library  \
# 0                                             Timgad
# 1                                            Hattusa
# 2                           Royal Library of Antioch
# 3                                Library of Pergamum
# 4                                  Library of Celsus
# 5            The Imperial Library of Constantinople
# 6                                Han Imperial Library
# 7                     The Royal Library of Alexandria
# 8                              Serapeum of Alexandria
# 9                     Temple of Edfu Archive/Library
# 10           The Library of AksumThe kingdom of Aksum
# 11                          The Library of Aristotle
# 12                                       Kos Library
# 13                          The Library of Pantainos
# 14                             The Library of Rhodes
# 15                                        Takshasila
# 16                                           Nalanda
# 17                                       Vikramshila
# 18                 Kanchipuram and other universities
# 19         The Academy of Gondishapur in western Iran
# 20                       The Library of Ashurbanipal
# 21                             Nippur temple library
# 22                                              Nuzi
# 23                               The House of Wisdom
# 24                             Libraries of the Forum
# 25  Atrium Liberatatis public library of Asinius P...
# 26                            The Villa of the Papyri
# 27       The Theological Library of Caesarea Maritima
# 28                                              Ebla
# 29                                            Ugarit
# 30                                       Tell Leilan
# 31                                              Mari
# 32                              Sufiya Mosque Library
#
#                                         test  \
# 0                                     Timgad
# 1                                    Hattusa
# 2                         Library of Antioch
# 3                        Library of Pergamum
# 4                          Library of Celsus
# 5         Imperial Library of Constantinople
# 6                                       None
# 7                      Library of Alexandria
# 8                     Serapeum of Alexandria
# 9                                       None
# 10                                      None
# 11                                      None
# 12                                      None
# 13                                      None
# 14                                      None
# 15                                      None
# 16                                   Nalanda
# 17                              Vikramashila
# 18                                      None
# 19                                      None
# 20                   Library of Ashurbanipal
# 21                                      None
# 22                                      Nuzi
# 23                           House of Wisdom
# 24                                      None
# 25                                      None
# 26                       Villa of the Papyri
# 27  Theological Library of Caesarea Maritima
# 28                                      Ebla
# 29                                    Ugarit
# 30                               Tell Leilan
# 31                                      None
# 32                                      None
#
#                                                 Links  \
# 0                https://en.wikipedia.org/wiki/Timgad
# 1               https://en.wikipedia.org/wiki/Hattusa
# 2    https://en.wikipedia.org/wiki/Library_of_Antioch
# 3   https://en.wikipedia.org/wiki/Library_of_Pergamum
# 4     https://en.wikipedia.org/wiki/Library_of_Celsus
# 5   https://en.wikipedia.org/wiki/Imperial_Library...
# 6                                                None
# 7   https://en.wikipedia.org/wiki/Library_of_Alexa...
# 8   https://en.wikipedia.org/wiki/Serapeum_of_Alex...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16              https://en.wikipedia.org/wiki/Nalanda
# 17         https://en.wikipedia.org/wiki/Vikramashila
# 18                                               None
# 19                                               None
# 20  https://en.wikipedia.org/wiki/Library_of_Ashur...
# 21                                               None
# 22                 https://en.wikipedia.org/wiki/Nuzi
# 23      https://en.wikipedia.org/wiki/House_of_Wisdom
# 24                                               None
# 25                                               None
# 26  https://en.wikipedia.org/wiki/Villa_of_the_Papyri
# 27  https://en.wikipedia.org/wiki/Theological_Libr...
# 28                 https://en.wikipedia.org/wiki/Ebla
# 29               https://en.wikipedia.org/wiki/Ugarit
# 30          https://en.wikipedia.org/wiki/Tell_Leilan
# 31                                               None
# 32                                               None
#
#                                          tmp  \
# 0                                     Timgad
# 1                                    Hattusa
# 2                         Library of Antioch
# 3                        Library of Pergamum
# 4                          Library of Celsus
# 5         Imperial Library of Constantinople
# 6                                        NaN
# 7                      Library of Alexandria
# 8                     Serapeum of Alexandria
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                   Nalanda
# 17                              Vikramashila
# 18                                       NaN
# 19                                       NaN
# 20                   Library of Ashurbanipal
# 21                                       NaN
# 22                                      Nuzi
# 23                           House of Wisdom
# 24                                       NaN
# 25                                       NaN
# 26                       Villa of the Papyri
# 27  Theological Library of Caesarea Maritima
# 28                                      Ebla
# 29                                    Ugarit
# 30                               Tell Leilan
# 31                                       NaN
# 32                                       NaN
#
#                                  Loc_F  Start_Date    End_Date
# 0                       modern Algeria    250 A.D.         NaN
# 1                      modern Bogazkoy  1900 B.C.    1190 B.C.
# 2                       Modern Antakya   221 B.C.     363 A.D.
# 3                       modern Bergama   197 B.C.     159 B.C.
# 4   located within the city of Ephesus   135 A.D.     262 A.D.
# 5      Constantinople, modern Istanbul    337 A.D.   361 A.D.
# 6                                    0         NaN         NaN
# 7                                    0         NaN         NaN
# 8                                    0         NaN         NaN
# 9                                    0    237 B.C.     57 B.C.
# 10                                   0         NaN         NaN
# 11                              Athens    384 B.C.    321 B.C.
# 12                                 Kos    100 A.D.         NaN
# 13                              Athens    100 A.D.         NaN
# 14                              Rhodes    100 A.D.         NaN
# 15                                   0   6th  B.C.      5 B.C.
# 16                                   0         NaN         NaN
# 17                                   0      8 A.D.         NaN
# 18                                   0         NaN         NaN
# 19                                   0         NaN         NaN
# 20             near modern Mosul, Iraq         NaN         NaN
# 21                                   0   2500 B.C.         NaN
# 22                  Modern Yorgan Tepe   1500 B.C.         NaN
# 23                             Baghdad      9 A.D.     13 A.D.
# 24                                   0         NaN         NaN
# 25                                   0         NaN         NaN
# 26                                   0         NaN         NaN
# 27                                   0         NaN         NaN
# 28                                   0  2500 B.C.    2250 B.C.
# 29                   Modern Ras Shamra   1200 B.C.         NaN
# 30                     Northeast Syria   1900 B.C.         NaN
# 31                  Modern Tell Hariri   1900 B.C.         NaN
# 32                              Aleppo     12 A.D.         NaN

# %% [markdown]
# # Cleaning up location column

# %%
##Removing modern terms
df3['Location'] = df3['Loc_F'].str.lstrip('Modern |modern |ar modern')
##Cheats
df3['Location'].replace({'located within the city of Ephesus': 'Ephesus'},inplace =True)
df3['Location'].replace({'Constantinople, modern Istanbul': 'Istanbul'},inplace =True)
df3['Location'].replace({'sul, Iraq': 'Sul'},inplace =True)
df3['Location'].replace({'Northeast Syria': None},inplace =True)
df3['Location'].replace({'Algeria': None},inplace =True)
df3 = df3.drop(['Loc_F'], axis=1)
df3['Loc_Geo'] = df3['Location'] + ', ' + df3['NAME']
df3
# Out:
#                                              RAW_TEXT      NAME  \
# 0   Timgad (250 A.D.) (modern Algeria)The library ...   Algeria
# 1   Hattusa (1900 B.C. - 1190 B.C.) (modern Bogazk...    Turkey
# 2   Royal Library of Antioch (221 B.C. - 363 A.D.)...    Turkey
# 3   Library of Pergamum (197 B.C. - 159 B.C.) (mod...    Turkey
# 4   Library of Celsus (135 A.D. - 262) (located wi...    Turkey
# 5   The Imperial Library of Constantinople  (337â€...    Turkey
# 6   Han Imperial Library. Catalogue preserved in t...     China
# 7   The Royal Library of Alexandria, Egypt, fl. 3r...     Egypt
# 8   Serapeum of Alexandria, offshoot collection of...     Egypt
# 9   Temple of Edfu Archive/Library (237â€“57 B.C.)...     Egypt
# 10  The Library of AksumThe kingdom of Aksum, by t...  Ethiopia
# 11  The Library of Aristotle (Athens) (384â€“321 B...    Greece
# 12  Kos Library (Kos) (100 A.D.)The library was a ...    Greece
# 13  The Library of Pantainos (Athens) (100 A.D.)De...    Greece
# 14  The Library of Rhodes (Rhodes) (100 A.D.)The l...    Greece
# 15  Takshasila (6th to 5th century BC in modern-da...     India
# 16  Nalanda (founded in 427) was considered "one o...     India
# 17                          Vikramshila (8th century)     India
# 18  Kanchipuram and other universities, also maint...     India
# 19  The Academy of Gondishapur in western Iran, es...      Iran
# 20  The Library of Ashurbanipal (established 668â€...      Iraq
# 21  Nippur temple library (2500 B.C.)The earliest ...      Iraq
# 22  Nuzi (Modern Yorgan Tepe) (1500 B.C.)This arch...      Iraq
# 23  The House of Wisdom (Baghdad) (9thâ€“13th cent...      Iraq
# 24  Libraries of the Forum, consisted of separate ...     Italy
# 25  Atrium Liberatatis public library of Asinius P...     Italy
# 26  The Villa of the Papyri, in Herculaneum, Italy...     Italy
# 27  The Theological Library of Caesarea Maritima, ...    Israel
# 28  Ebla (2500 B.C. â€“ 2250 B.C.)Constitute the o...     Syria
# 29  Ugarit (Modern Ras Shamra) (1200 B.C.)Several ...     Syria
# 30  Tell Leilan (Northeast Syria) (1900 B.C.)This ...     Syria
# 31  Mari (Modern Tell Hariri) (1900 B.C.)The archi...     Syria
# 32  Sufiya Mosque Library, Grand Umayyad Mosque (A...     Syria
#
#                                                 Extra  \
# 0   The library was a gift to the Roman people and...
# 1   This archive constituted the largest collectio...
# 2   The library was commissioned in the third cent...
# 3   The Attalid kings formed the second best Helle...
# 4   This library was part of the triumvirate of li...
# 5   The library was established by Constantius II ...
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  The Library of Aristotle was a private library...
# 12  The library was a local public library situate...
# 13  Dedicated to both Athena Archegetis and the Ro...
# 14  The library on the island of Rhodes was a dist...
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  Long considered to be the first systematically...
# 21                                               None
# 22  This archive consisted of over 6,000 tablets w...
# 23  An Abbasid-era library and Arabic translation ...
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29  Several thousand texts consisting of diplomati...
# 30   This archive housed over a thousand clay tablets
# 31  The archive held approximately 15,000 tablets ...
# 32  More than 10,000 volumes were housed in this l...
#
#                                               Library  \
# 0                                             Timgad
# 1                                            Hattusa
# 2                           Royal Library of Antioch
# 3                                Library of Pergamum
# 4                                  Library of Celsus
# 5            The Imperial Library of Constantinople
# 6                                Han Imperial Library
# 7                     The Royal Library of Alexandria
# 8                              Serapeum of Alexandria
# 9                     Temple of Edfu Archive/Library
# 10           The Library of AksumThe kingdom of Aksum
# 11                          The Library of Aristotle
# 12                                       Kos Library
# 13                          The Library of Pantainos
# 14                             The Library of Rhodes
# 15                                        Takshasila
# 16                                           Nalanda
# 17                                       Vikramshila
# 18                 Kanchipuram and other universities
# 19         The Academy of Gondishapur in western Iran
# 20                       The Library of Ashurbanipal
# 21                             Nippur temple library
# 22                                              Nuzi
# 23                               The House of Wisdom
# 24                             Libraries of the Forum
# 25  Atrium Liberatatis public library of Asinius P...
# 26                            The Villa of the Papyri
# 27       The Theological Library of Caesarea Maritima
# 28                                              Ebla
# 29                                            Ugarit
# 30                                       Tell Leilan
# 31                                              Mari
# 32                              Sufiya Mosque Library
#
#                                         test  \
# 0                                     Timgad
# 1                                    Hattusa
# 2                         Library of Antioch
# 3                        Library of Pergamum
# 4                          Library of Celsus
# 5         Imperial Library of Constantinople
# 6                                       None
# 7                      Library of Alexandria
# 8                     Serapeum of Alexandria
# 9                                       None
# 10                                      None
# 11                                      None
# 12                                      None
# 13                                      None
# 14                                      None
# 15                                      None
# 16                                   Nalanda
# 17                              Vikramashila
# 18                                      None
# 19                                      None
# 20                   Library of Ashurbanipal
# 21                                      None
# 22                                      Nuzi
# 23                           House of Wisdom
# 24                                      None
# 25                                      None
# 26                       Villa of the Papyri
# 27  Theological Library of Caesarea Maritima
# 28                                      Ebla
# 29                                    Ugarit
# 30                               Tell Leilan
# 31                                      None
# 32                                      None
#
#                                                 Links  \
# 0                https://en.wikipedia.org/wiki/Timgad
# 1               https://en.wikipedia.org/wiki/Hattusa
# 2    https://en.wikipedia.org/wiki/Library_of_Antioch
# 3   https://en.wikipedia.org/wiki/Library_of_Pergamum
# 4     https://en.wikipedia.org/wiki/Library_of_Celsus
# 5   https://en.wikipedia.org/wiki/Imperial_Library...
# 6                                                None
# 7   https://en.wikipedia.org/wiki/Library_of_Alexa...
# 8   https://en.wikipedia.org/wiki/Serapeum_of_Alex...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16              https://en.wikipedia.org/wiki/Nalanda
# 17         https://en.wikipedia.org/wiki/Vikramashila
# 18                                               None
# 19                                               None
# 20  https://en.wikipedia.org/wiki/Library_of_Ashur...
# 21                                               None
# 22                 https://en.wikipedia.org/wiki/Nuzi
# 23      https://en.wikipedia.org/wiki/House_of_Wisdom
# 24                                               None
# 25                                               None
# 26  https://en.wikipedia.org/wiki/Villa_of_the_Papyri
# 27  https://en.wikipedia.org/wiki/Theological_Libr...
# 28                 https://en.wikipedia.org/wiki/Ebla
# 29               https://en.wikipedia.org/wiki/Ugarit
# 30          https://en.wikipedia.org/wiki/Tell_Leilan
# 31                                               None
# 32                                               None
#
#                                          tmp  Start_Date    End_Date  \
# 0                                     Timgad    250 A.D.         NaN
# 1                                    Hattusa  1900 B.C.    1190 B.C.
# 2                         Library of Antioch   221 B.C.     363 A.D.
# 3                        Library of Pergamum   197 B.C.     159 B.C.
# 4                          Library of Celsus   135 A.D.     262 A.D.
# 5         Imperial Library of Constantinople    337 A.D.   361 A.D.
# 6                                        NaN         NaN         NaN
# 7                      Library of Alexandria         NaN         NaN
# 8                     Serapeum of Alexandria         NaN         NaN
# 9                                        NaN    237 B.C.     57 B.C.
# 10                                       NaN         NaN         NaN
# 11                                       NaN    384 B.C.    321 B.C.
# 12                                       NaN    100 A.D.         NaN
# 13                                       NaN    100 A.D.         NaN
# 14                                       NaN    100 A.D.         NaN
# 15                                       NaN   6th  B.C.      5 B.C.
# 16                                   Nalanda         NaN         NaN
# 17                              Vikramashila      8 A.D.         NaN
# 18                                       NaN         NaN         NaN
# 19                                       NaN         NaN         NaN
# 20                   Library of Ashurbanipal         NaN         NaN
# 21                                       NaN   2500 B.C.         NaN
# 22                                      Nuzi   1500 B.C.         NaN
# 23                           House of Wisdom      9 A.D.     13 A.D.
# 24                                       NaN         NaN         NaN
# 25                                       NaN         NaN         NaN
# 26                       Villa of the Papyri         NaN         NaN
# 27  Theological Library of Caesarea Maritima         NaN         NaN
# 28                                      Ebla  2500 B.C.    2250 B.C.
# 29                                    Ugarit   1200 B.C.         NaN
# 30                               Tell Leilan   1900 B.C.         NaN
# 31                                       NaN   1900 B.C.         NaN
# 32                                       NaN     12 A.D.         NaN
#
#        Location             Loc_Geo
# 0          None                 NaN
# 1      Bogazkoy    Bogazkoy, Turkey
# 2       Antakya     Antakya, Turkey
# 3       Bergama     Bergama, Turkey
# 4       Ephesus     Ephesus, Turkey
# 5      Istanbul    Istanbul, Turkey
# 6           NaN                 NaN
# 7           NaN                 NaN
# 8           NaN                 NaN
# 9           NaN                 NaN
# 10          NaN                 NaN
# 11       Athens      Athens, Greece
# 12          Kos         Kos, Greece
# 13       Athens      Athens, Greece
# 14       Rhodes      Rhodes, Greece
# 15          NaN                 NaN
# 16          NaN                 NaN
# 17          NaN                 NaN
# 18          NaN                 NaN
# 19          NaN                 NaN
# 20          Sul           Sul, Iraq
# 21          NaN                 NaN
# 22  Yorgan Tepe   Yorgan Tepe, Iraq
# 23      Baghdad       Baghdad, Iraq
# 24          NaN                 NaN
# 25          NaN                 NaN
# 26          NaN                 NaN
# 27          NaN                 NaN
# 28          NaN                 NaN
# 29   Ras Shamra   Ras Shamra, Syria
# 30         None                 NaN
# 31  Tell Hariri  Tell Hariri, Syria
# 32       Aleppo       Aleppo, Syria

# %%
df3['Start_Date_Y']  = np.where(df3['Start_Date'].str.contains('B.C.'), df3['Start_Date'], 0)
df3['Start_Date_Y'] = df3['Start_Date_Y'].str.replace('B.C.|th','')
df3['Start_Date_Y'] = ('-' + df3['Start_Date_Y'])
df3["Start_Date_Y"] = df3["Start_Date_Y"].fillna(0)
df3.loc[df3["Start_Date_Y"]== 0 ,"Start_Date_Y"] = df3['Start_Date']
df3['Start_Date_Y'] = df3['Start_Date_Y'].str.replace('A.D.','')
df3['Start_Date']= df3['Start_Date'].replace(np.nan, 'Unknown', regex=True)
df3
# Out:
#                                              RAW_TEXT      NAME  \
# 0   Timgad (250 A.D.) (modern Algeria)The library ...   Algeria
# 1   Hattusa (1900 B.C. - 1190 B.C.) (modern Bogazk...    Turkey
# 2   Royal Library of Antioch (221 B.C. - 363 A.D.)...    Turkey
# 3   Library of Pergamum (197 B.C. - 159 B.C.) (mod...    Turkey
# 4   Library of Celsus (135 A.D. - 262) (located wi...    Turkey
# 5   The Imperial Library of Constantinople  (337â€...    Turkey
# 6   Han Imperial Library. Catalogue preserved in t...     China
# 7   The Royal Library of Alexandria, Egypt, fl. 3r...     Egypt
# 8   Serapeum of Alexandria, offshoot collection of...     Egypt
# 9   Temple of Edfu Archive/Library (237â€“57 B.C.)...     Egypt
# 10  The Library of AksumThe kingdom of Aksum, by t...  Ethiopia
# 11  The Library of Aristotle (Athens) (384â€“321 B...    Greece
# 12  Kos Library (Kos) (100 A.D.)The library was a ...    Greece
# 13  The Library of Pantainos (Athens) (100 A.D.)De...    Greece
# 14  The Library of Rhodes (Rhodes) (100 A.D.)The l...    Greece
# 15  Takshasila (6th to 5th century BC in modern-da...     India
# 16  Nalanda (founded in 427) was considered "one o...     India
# 17                          Vikramshila (8th century)     India
# 18  Kanchipuram and other universities, also maint...     India
# 19  The Academy of Gondishapur in western Iran, es...      Iran
# 20  The Library of Ashurbanipal (established 668â€...      Iraq
# 21  Nippur temple library (2500 B.C.)The earliest ...      Iraq
# 22  Nuzi (Modern Yorgan Tepe) (1500 B.C.)This arch...      Iraq
# 23  The House of Wisdom (Baghdad) (9thâ€“13th cent...      Iraq
# 24  Libraries of the Forum, consisted of separate ...     Italy
# 25  Atrium Liberatatis public library of Asinius P...     Italy
# 26  The Villa of the Papyri, in Herculaneum, Italy...     Italy
# 27  The Theological Library of Caesarea Maritima, ...    Israel
# 28  Ebla (2500 B.C. â€“ 2250 B.C.)Constitute the o...     Syria
# 29  Ugarit (Modern Ras Shamra) (1200 B.C.)Several ...     Syria
# 30  Tell Leilan (Northeast Syria) (1900 B.C.)This ...     Syria
# 31  Mari (Modern Tell Hariri) (1900 B.C.)The archi...     Syria
# 32  Sufiya Mosque Library, Grand Umayyad Mosque (A...     Syria
#
#                                                 Extra  \
# 0   The library was a gift to the Roman people and...
# 1   This archive constituted the largest collectio...
# 2   The library was commissioned in the third cent...
# 3   The Attalid kings formed the second best Helle...
# 4   This library was part of the triumvirate of li...
# 5   The library was established by Constantius II ...
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  The Library of Aristotle was a private library...
# 12  The library was a local public library situate...
# 13  Dedicated to both Athena Archegetis and the Ro...
# 14  The library on the island of Rhodes was a dist...
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  Long considered to be the first systematically...
# 21                                               None
# 22  This archive consisted of over 6,000 tablets w...
# 23  An Abbasid-era library and Arabic translation ...
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29  Several thousand texts consisting of diplomati...
# 30   This archive housed over a thousand clay tablets
# 31  The archive held approximately 15,000 tablets ...
# 32  More than 10,000 volumes were housed in this l...
#
#                                               Library  \
# 0                                             Timgad
# 1                                            Hattusa
# 2                           Royal Library of Antioch
# 3                                Library of Pergamum
# 4                                  Library of Celsus
# 5            The Imperial Library of Constantinople
# 6                                Han Imperial Library
# 7                     The Royal Library of Alexandria
# 8                              Serapeum of Alexandria
# 9                     Temple of Edfu Archive/Library
# 10           The Library of AksumThe kingdom of Aksum
# 11                          The Library of Aristotle
# 12                                       Kos Library
# 13                          The Library of Pantainos
# 14                             The Library of Rhodes
# 15                                        Takshasila
# 16                                           Nalanda
# 17                                       Vikramshila
# 18                 Kanchipuram and other universities
# 19         The Academy of Gondishapur in western Iran
# 20                       The Library of Ashurbanipal
# 21                             Nippur temple library
# 22                                              Nuzi
# 23                               The House of Wisdom
# 24                             Libraries of the Forum
# 25  Atrium Liberatatis public library of Asinius P...
# 26                            The Villa of the Papyri
# 27       The Theological Library of Caesarea Maritima
# 28                                              Ebla
# 29                                            Ugarit
# 30                                       Tell Leilan
# 31                                              Mari
# 32                              Sufiya Mosque Library
#
#                                         test  \
# 0                                     Timgad
# 1                                    Hattusa
# 2                         Library of Antioch
# 3                        Library of Pergamum
# 4                          Library of Celsus
# 5         Imperial Library of Constantinople
# 6                                       None
# 7                      Library of Alexandria
# 8                     Serapeum of Alexandria
# 9                                       None
# 10                                      None
# 11                                      None
# 12                                      None
# 13                                      None
# 14                                      None
# 15                                      None
# 16                                   Nalanda
# 17                              Vikramashila
# 18                                      None
# 19                                      None
# 20                   Library of Ashurbanipal
# 21                                      None
# 22                                      Nuzi
# 23                           House of Wisdom
# 24                                      None
# 25                                      None
# 26                       Villa of the Papyri
# 27  Theological Library of Caesarea Maritima
# 28                                      Ebla
# 29                                    Ugarit
# 30                               Tell Leilan
# 31                                      None
# 32                                      None
#
#                                                 Links  \
# 0                https://en.wikipedia.org/wiki/Timgad
# 1               https://en.wikipedia.org/wiki/Hattusa
# 2    https://en.wikipedia.org/wiki/Library_of_Antioch
# 3   https://en.wikipedia.org/wiki/Library_of_Pergamum
# 4     https://en.wikipedia.org/wiki/Library_of_Celsus
# 5   https://en.wikipedia.org/wiki/Imperial_Library...
# 6                                                None
# 7   https://en.wikipedia.org/wiki/Library_of_Alexa...
# 8   https://en.wikipedia.org/wiki/Serapeum_of_Alex...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16              https://en.wikipedia.org/wiki/Nalanda
# 17         https://en.wikipedia.org/wiki/Vikramashila
# 18                                               None
# 19                                               None
# 20  https://en.wikipedia.org/wiki/Library_of_Ashur...
# 21                                               None
# 22                 https://en.wikipedia.org/wiki/Nuzi
# 23      https://en.wikipedia.org/wiki/House_of_Wisdom
# 24                                               None
# 25                                               None
# 26  https://en.wikipedia.org/wiki/Villa_of_the_Papyri
# 27  https://en.wikipedia.org/wiki/Theological_Libr...
# 28                 https://en.wikipedia.org/wiki/Ebla
# 29               https://en.wikipedia.org/wiki/Ugarit
# 30          https://en.wikipedia.org/wiki/Tell_Leilan
# 31                                               None
# 32                                               None
#
#                                          tmp  Start_Date    End_Date  \
# 0                                     Timgad    250 A.D.         NaN
# 1                                    Hattusa  1900 B.C.    1190 B.C.
# 2                         Library of Antioch   221 B.C.     363 A.D.
# 3                        Library of Pergamum   197 B.C.     159 B.C.
# 4                          Library of Celsus   135 A.D.     262 A.D.
# 5         Imperial Library of Constantinople    337 A.D.   361 A.D.
# 6                                        NaN     Unknown         NaN
# 7                      Library of Alexandria     Unknown         NaN
# 8                     Serapeum of Alexandria     Unknown         NaN
# 9                                        NaN    237 B.C.     57 B.C.
# 10                                       NaN     Unknown         NaN
# 11                                       NaN    384 B.C.    321 B.C.
# 12                                       NaN    100 A.D.         NaN
# 13                                       NaN    100 A.D.         NaN
# 14                                       NaN    100 A.D.         NaN
# 15                                       NaN   6th  B.C.      5 B.C.
# 16                                   Nalanda     Unknown         NaN
# 17                              Vikramashila      8 A.D.         NaN
# 18                                       NaN     Unknown         NaN
# 19                                       NaN     Unknown         NaN
# 20                   Library of Ashurbanipal     Unknown         NaN
# 21                                       NaN   2500 B.C.         NaN
# 22                                      Nuzi   1500 B.C.         NaN
# 23                           House of Wisdom      9 A.D.     13 A.D.
# 24                                       NaN     Unknown         NaN
# 25                                       NaN     Unknown         NaN
# 26                       Villa of the Papyri     Unknown         NaN
# 27  Theological Library of Caesarea Maritima     Unknown         NaN
# 28                                      Ebla  2500 B.C.    2250 B.C.
# 29                                    Ugarit   1200 B.C.         NaN
# 30                               Tell Leilan   1900 B.C.         NaN
# 31                                       NaN   1900 B.C.         NaN
# 32                                       NaN     12 A.D.         NaN
#
#        Location             Loc_Geo Start_Date_Y
# 0          None                 NaN         250
# 1      Bogazkoy    Bogazkoy, Turkey      -1900
# 2       Antakya     Antakya, Turkey       -221
# 3       Bergama     Bergama, Turkey       -197
# 4       Ephesus     Ephesus, Turkey        135
# 5      Istanbul    Istanbul, Turkey         337
# 6           NaN                 NaN          NaN
# 7           NaN                 NaN          NaN
# 8           NaN                 NaN          NaN
# 9           NaN                 NaN        -237
# 10          NaN                 NaN          NaN
# 11       Athens      Athens, Greece        -384
# 12          Kos         Kos, Greece         100
# 13       Athens      Athens, Greece         100
# 14       Rhodes      Rhodes, Greece         100
# 15          NaN                 NaN         -6
# 16          NaN                 NaN          NaN
# 17          NaN                 NaN           8
# 18          NaN                 NaN          NaN
# 19          NaN                 NaN          NaN
# 20          Sul           Sul, Iraq          NaN
# 21          NaN                 NaN       -2500
# 22  Yorgan Tepe   Yorgan Tepe, Iraq       -1500
# 23      Baghdad       Baghdad, Iraq           9
# 24          NaN                 NaN          NaN
# 25          NaN                 NaN          NaN
# 26          NaN                 NaN          NaN
# 27          NaN                 NaN          NaN
# 28          NaN                 NaN      -2500
# 29   Ras Shamra   Ras Shamra, Syria       -1200
# 30         None                 NaN       -1900
# 31  Tell Hariri  Tell Hariri, Syria       -1900
# 32       Aleppo       Aleppo, Syria          12

# %% [markdown]
# # Pulling coodrinates for locations

# %%
##Drop nulls
libs_cityloc =  df3.loc[df3.Loc_Geo.notnull()]
##Using geopy to extract coordinates from place name and location back to dataframe
geolocator = Nominatim()
libs_cityloc_ = libs_cityloc.filter(['Loc_Geo'], axis=1)
libs_cityloc_
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
libs_cityloc_['location'] = libs_cityloc_['Loc_Geo'].apply(geocode)
libs_cityloc_['point'] = libs_cityloc_['location'].apply(lambda loc: tuple(loc.point) if loc else None)
libs_cityloc = pd.merge(libs_cityloc, libs_cityloc_, how='left', on= 'Loc_Geo')
# Out:
# C:\Users\fcmun\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   after removing the cwd from sys.path.
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Kos, Greece',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\fcmun\Anaconda3\lib\urllib\request.py", line 1318, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\Users\fcmun\Anaconda3\lib\http\client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\Users\fcmun\Anaconda3\lib\http\client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\Users\fcmun\Anaconda3\lib\http\client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\Users\fcmun\Anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\Users\fcmun\Anaconda3\lib\http\client.py", line 964, in send
#     self.connect()
#   File "C:\Users\fcmun\Anaconda3\lib\http\client.py", line 1400, in connect
#     server_hostname=server_hostname)
#   File "C:\Users\fcmun\Anaconda3\lib\ssl.py", line 407, in wrap_socket
#     _context=self, _session=session)
#   File "C:\Users\fcmun\Anaconda3\lib\ssl.py", line 814, in __init__
#     self.do_handshake()
#   File "C:\Users\fcmun\Anaconda3\lib\ssl.py", line 1068, in do_handshake
#     self._sslobj.do_handshake()
#   File "C:\Users\fcmun\Anaconda3\lib\ssl.py", line 689, in do_handshake
#     self._sslobj.do_handshake()
# socket.timeout: _ssl.c:825: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\fcmun\Anaconda3\lib\site-packages\geopy\geocoders\base.py", line 344, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\Users\fcmun\Anaconda3\lib\urllib\request.py", line 526, in open
#     response = self._open(req, data)
#   File "C:\Users\fcmun\Anaconda3\lib\urllib\request.py", line 544, in _open
#     '_open', req)
#   File "C:\Users\fcmun\Anaconda3\lib\urllib\request.py", line 504, in _call_chain
#     result = func(*args)
#   File "C:\Users\fcmun\Anaconda3\lib\urllib\request.py", line 1361, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\fcmun\Anaconda3\lib\urllib\request.py", line 1320, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error _ssl.c:825: The handshake operation timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\fcmun\Anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\fcmun\Anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 309, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\Users\fcmun\Anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out

# %%
#Locations are stored as tuples, split it up and create lat/lon column
libs_cityloc =  libs_cityloc.loc[libs_cityloc.point.notnull()]
tmp = pd.DataFrame(libs_cityloc['point'].tolist(), index=libs_cityloc.index)   
libs_cityloc['Lat']=tmp[0]
libs_cityloc['Lon']=tmp[1]
libs_cityloc['Info'] = libs_cityloc['Library'] + ', Creation Date: ' + libs_cityloc['Start_Date'] + ', Wiki link: ' + libs_cityloc['Links']
##libs_cityloc['Info']= libs_cityloc['Info'].replace(np.nan, 'No Info', regex=True)
libs_cityloc
# Out:
# C:\Users\fcmun\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\fcmun\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\fcmun\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                              RAW_TEXT    NAME  \
# 0   Hattusa (1900 B.C. - 1190 B.C.) (modern Bogazk...  Turkey
# 1   Royal Library of Antioch (221 B.C. - 363 A.D.)...  Turkey
# 2   Library of Pergamum (197 B.C. - 159 B.C.) (mod...  Turkey
# 3   Library of Celsus (135 A.D. - 262) (located wi...  Turkey
# 4   The Imperial Library of Constantinople  (337â€...  Turkey
# 5   The Library of Aristotle (Athens) (384â€“321 B...  Greece
# 6   The Library of Aristotle (Athens) (384â€“321 B...  Greece
# 7   Kos Library (Kos) (100 A.D.)The library was a ...  Greece
# 8   The Library of Pantainos (Athens) (100 A.D.)De...  Greece
# 9   The Library of Pantainos (Athens) (100 A.D.)De...  Greece
# 10  The Library of Rhodes (Rhodes) (100 A.D.)The l...  Greece
# 11  The Library of Ashurbanipal (established 668â€...    Iraq
# 13  The House of Wisdom (Baghdad) (9thâ€“13th cent...    Iraq
# 14  Ugarit (Modern Ras Shamra) (1200 B.C.)Several ...   Syria
# 16  Sufiya Mosque Library, Grand Umayyad Mosque (A...   Syria
#
#                                                 Extra  \
# 0   This archive constituted the largest collectio...
# 1   The library was commissioned in the third cent...
# 2   The Attalid kings formed the second best Helle...
# 3   This library was part of the triumvirate of li...
# 4   The library was established by Constantius II ...
# 5   The Library of Aristotle was a private library...
# 6   The Library of Aristotle was a private library...
# 7   The library was a local public library situate...
# 8   Dedicated to both Athena Archegetis and the Ro...
# 9   Dedicated to both Athena Archegetis and the Ro...
# 10  The library on the island of Rhodes was a dist...
# 11  Long considered to be the first systematically...
# 13  An Abbasid-era library and Arabic translation ...
# 14  Several thousand texts consisting of diplomati...
# 16  More than 10,000 volumes were housed in this l...
#
#                                      Library  \
# 0                                   Hattusa
# 1                  Royal Library of Antioch
# 2                       Library of Pergamum
# 3                         Library of Celsus
# 4   The Imperial Library of Constantinople
# 5                  The Library of Aristotle
# 6                  The Library of Aristotle
# 7                               Kos Library
# 8                  The Library of Pantainos
# 9                  The Library of Pantainos
# 10                    The Library of Rhodes
# 11              The Library of Ashurbanipal
# 13                      The House of Wisdom
# 14                                   Ugarit
# 16                     Sufiya Mosque Library
#
#                                   test  \
# 0                              Hattusa
# 1                   Library of Antioch
# 2                  Library of Pergamum
# 3                    Library of Celsus
# 4   Imperial Library of Constantinople
# 5                                 None
# 6                                 None
# 7                                 None
# 8                                 None
# 9                                 None
# 10                                None
# 11             Library of Ashurbanipal
# 13                     House of Wisdom
# 14                              Ugarit
# 16                                None
#
#                                                 Links  \
# 0               https://en.wikipedia.org/wiki/Hattusa
# 1    https://en.wikipedia.org/wiki/Library_of_Antioch
# 2   https://en.wikipedia.org/wiki/Library_of_Pergamum
# 3     https://en.wikipedia.org/wiki/Library_of_Celsus
# 4   https://en.wikipedia.org/wiki/Imperial_Library...
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  https://en.wikipedia.org/wiki/Library_of_Ashur...
# 13      https://en.wikipedia.org/wiki/House_of_Wisdom
# 14               https://en.wikipedia.org/wiki/Ugarit
# 16                                               None
#
#                                    tmp  Start_Date    End_Date    Location  \
# 0                              Hattusa  1900 B.C.    1190 B.C.    Bogazkoy
# 1                   Library of Antioch   221 B.C.     363 A.D.     Antakya
# 2                  Library of Pergamum   197 B.C.     159 B.C.     Bergama
# 3                    Library of Celsus   135 A.D.     262 A.D.     Ephesus
# 4   Imperial Library of Constantinople    337 A.D.   361 A.D.     Istanbul
# 5                                  NaN    384 B.C.    321 B.C.      Athens
# 6                                  NaN    384 B.C.    321 B.C.      Athens
# 7                                  NaN    100 A.D.         NaN         Kos
# 8                                  NaN    100 A.D.         NaN      Athens
# 9                                  NaN    100 A.D.         NaN      Athens
# 10                                 NaN    100 A.D.         NaN      Rhodes
# 11             Library of Ashurbanipal     Unknown         NaN         Sul
# 13                     House of Wisdom      9 A.D.     13 A.D.     Baghdad
# 14                              Ugarit   1200 B.C.         NaN  Ras Shamra
# 16                                 NaN     12 A.D.         NaN      Aleppo
#
#               Loc_Geo Start_Date_Y  \
# 0    Bogazkoy, Turkey      -1900
# 1     Antakya, Turkey       -221
# 2     Bergama, Turkey       -197
# 3     Ephesus, Turkey        135
# 4    Istanbul, Turkey         337
# 5      Athens, Greece        -384
# 6      Athens, Greece        -384
# 7         Kos, Greece         100
# 8      Athens, Greece         100
# 9      Athens, Greece         100
# 10     Rhodes, Greece         100
# 11          Sul, Iraq          NaN
# 13      Baghdad, Iraq           9
# 14  Ras Shamra, Syria       -1200
# 16      Aleppo, Syria          12
#
#                                              location  \
# 0   (Boğazköy, Nevşehir merkez, Nevşehir, İç Anado...
# 1   (Antakya, Antakya (merkez), Hatay, Akdeniz Böl...
# 2   (Bergama, İzmir, Ege Bölgesi, 35700, Türkiye, ...
# 3   (Efes, Arkadiane, Selçuk, İzmir, Ege Bölgesi, ...
# 4   (İstanbul, Fatih, İstanbul, Marmara Bölgesi, 3...
# 5   (Αθήνα, Δήμος Αθηναίων, Π.Ε. Κεντρικού Τομέα Α...
# 6   (Αθήνα, Δήμος Αθηναίων, Π.Ε. Κεντρικού Τομέα Α...
# 7   (Δήμος Κω, Περιφερειακή Ενότητα Κω, Περιφέρεια...
# 8   (Αθήνα, Δήμος Αθηναίων, Π.Ε. Κεντρικού Τομέα Α...
# 9   (Αθήνα, Δήμος Αθηναίων, Π.Ε. Κεντρικού Τομέα Α...
# 10  (Ρόδος, Δήμος Ρόδου, Περιφερειακή Ενότητα Ρόδο...
# 11  (قلالش سول, مخمور, هەولێر, هەرێمی کوردستان, ال...
# 13  (بغداد, الكرخ, محافظة بغداد, العراق, (33.30243...
# 14  (رأس شمرة, برج القصب, اللاذقية, سوريا, (35.605...
# 16  (حلب, منطقة جبل سمعان‎, حلب, 4545, سوريا, (36....
#
#                                    point        Lat        Lon  \
# 0          (38.5472734, 34.6360644, 0.0)  38.547273  34.636064
# 1          (36.2176872, 36.1653617, 0.0)  36.217687  36.165362
# 2          (39.1191544, 27.1777296, 0.0)  39.119154  27.177730
# 3   (37.94044555, 27.3393194464968, 0.0)  37.940446  27.339319
# 4          (41.0096334, 28.9651646, 0.0)  41.009633  28.965165
# 5          (37.9841493, 23.7279843, 0.0)  37.984149  23.727984
# 6          (37.9841493, 23.7279843, 0.0)  37.984149  23.727984
# 7    (36.7939719, 27.0850810793972, 0.0)  36.793972  27.085081
# 8          (37.9841493, 23.7279843, 0.0)  37.984149  23.727984
# 9          (37.9841493, 23.7279843, 0.0)  37.984149  23.727984
# 10         (36.4379874, 28.2233083, 0.0)  36.437987  28.223308
# 11           (35.718958, 43.672395, 0.0)  35.718958  43.672395
# 13         (33.3024309, 44.3787992, 0.0)  33.302431  44.378799
# 14         (35.6057226, 35.7819723, 0.0)  35.605723  35.781972
# 16           (36.19924, 37.1637253, 0.0)  36.199240  37.163725
#
#                                                  Info
# 0   Hattusa , Creation Date: 1900 B.C. , Wiki link...
# 1   Royal Library of Antioch , Creation Date: 221 ...
# 2   Library of Pergamum , Creation Date: 197 B.C. ...
# 3   Library of Celsus , Creation Date: 135 A.D. , ...
# 4   The Imperial Library of Constantinople  , Crea...
# 5   The Library of Aristotle , Creation Date: 384 ...
# 6   The Library of Aristotle , Creation Date: 384 ...
# 7   Kos Library , Creation Date: 100 A.D., Wiki li...
# 8   The Library of Pantainos , Creation Date: 100 ...
# 9   The Library of Pantainos , Creation Date: 100 ...
# 10  The Library of Rhodes , Creation Date: 100 A.D...
# 11  The Library of Ashurbanipal , Creation Date: U...
# 13  The House of Wisdom , Creation Date: 9 A.D., W...
# 14  Ugarit , Creation Date: 1200 B.C., Wiki link: ...
# 16  Sufiya Mosque Library, Creation Date: 12 A.D.,...

# %% [markdown]
# # Creating map that shows where Ancient Libraries were located (City Level)

# %%
mkr = folium.Map(location=[35.283731, 35.203442], tiles='stamenterrain', zoom_start=5)
libs_cityloc.apply(lambda row:folium.Marker(location=[row["Lat"], row["Lon"]], popup=row['Info'],).add_to(mkr),axis=1)
mkr.save(outfile= "Library_Locations.html")
mkr
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Create Chloropleth using Folium package. Save off as HTML file.

# %%
#Group data
groups = df2.groupby('NAME', as_index=False).count()
groups1 = groups.drop(['RAW_TEXT'], axis=1)

# %%
#Read in country shapefile and merge with groups to only keep countries that have ancient libraries.  Save the that geodataframe off as json file
geo_data = gpd.read_file(countries, encoding="utf-8")
country_shapes = geo_data.merge(groups, on='NAME', how='right')
geo_data.plot()
country_shapes.plot('NAME', cmap='OrRd', legend = True)
country_shapes = country_shapes[['NAME', 'geometry']]
country_shapes = country_shapes[pd.notnull(country_shapes['geometry'])]
country_shapes
country_shapes.to_file('country2.json', driver='GeoJSON')

# %%
##create cholorepleth showing counts of ancient libraries in each country
country_geo = os.path.join('country2.json')
m = folium.Map(location=[30.3755321, 69.345116], tiles='stamentoner', zoom_start=3)
m.choropleth(
 geo_data=country_geo,
 name='choropleth',
 data=groups,
 columns=['NAME', 'Library'],
 key_on='feature.properties.NAME',
 fill_color='BuGn',
 fill_opacity=0.7,
 line_opacity=0.0,
 legend_name='Libraries'
)
folium.LayerControl().add_to(m)
m.save(outfile= "Countries_LibraryCNT.html")
##os.remove("country2.json")
##os.remove("temp.txt")
m

# %% [markdown]
# # Extra Stuff

# %%
##geo_data.to_file('country.geojson', driver='GeoJSON')
##country_geo = os.path.join('country.geojson')
##https://deparkes.co.uk/2016/06/10/folium-map-tiles/
##https://stackoverflow.com/questions/53571106/choropleth-with-folium
##https://stackoverflow.com/questions/16842001/copy-text-between-parentheses-in-pandas-dataframe-column-into-another-column
##https://stackoverflow.com/questions/22588316/pandas-applying-regex-to-replace-values
##https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html
##https://stackoverflow.com/questions/15857797/bc-dates-in-python
##https://stackoverflow.com/questions/43089275/numpy-where-with-like-operator
##https://stackoverflow.com/questions/47723919/iterate-geolocation-over-pandas-dataframe
##https://automating-gis-processes.github.io/CSC18/lessons/L3/geocoding.html
##https://geopy.readthedocs.io/en/stable/#usage-with-pandas
##https://stackoverflow.com/questions/42756934/how-to-plot-lat-and-long-from-pandas-dataframe-on-folium-map-group-by-some-label
##https://stackoverflow.com/questions/35380933/how-to-merge-two-pandas-dataframes-based-on-a-similarity-function

# %%
##libs_cityloc['nameurl'] = libs_cityloc['Library'] + '#' + libs_cityloc['Key']
##def make_clickable_both(val): 
    ##name, url = val.split('#')
    ##return f'<a href="{url}">{name}</a>'

##libs_cityloc.reset_index().style.format({'nameurl': make_clickable_both})
